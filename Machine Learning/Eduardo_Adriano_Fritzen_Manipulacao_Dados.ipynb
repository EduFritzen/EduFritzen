# %% [markdown]
# # **Manipulação de Dados Tabulares com Pandas**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cidades = pd.DataFrame(
    [
        ['Paraná', 'Londrina', 575377, 1356.00],
        ['São Paulo', 'São Carlos', 254484, 1508.00],
        ['Santa Catarina', 'Florianópolis', 508826, 1798.00],
        ['Paraná', 'Curitiba', 1963726, 2293.00],
        ['São Paulo', 'Campinas', 1223237, 1710.00]
    ], columns=['Estado', 'Cidade', 'Habitantes', 'Salário-Médio'])

cidades
# Out:
#            Estado         Cidade  Habitantes  Salário-Médio
# 0          Paraná       Londrina      575377         1356.0
# 1       São Paulo     São Carlos      254484         1508.0
# 2  Santa Catarina  Florianópolis      508826         1798.0
# 3          Paraná       Curitiba     1963726         2293.0
# 4       São Paulo       Campinas     1223237         1710.0

# %%
cidades.head(2) # Retorna um novo dataframe com as n primeiras amostras
# Out:
#       Estado      Cidade  Habitantes  Salário-Médio
# 0     Paraná    Londrina      575377         1356.0
# 1  São Paulo  São Carlos      254484         1508.0

# %%
cidades.tail(2) # Retorna um novo dataframe com as n últimas amostras
# Out:
#       Estado    Cidade  Habitantes  Salário-Médio
# 3     Paraná  Curitiba     1963726         2293.0
# 4  São Paulo  Campinas     1223237         1710.0

# %%
cidades.shape # Retorna uma tupla com o número de linhas e colunas
# Out:
# (5, 4)

# %%
cidades.info() # Retorna vazio e imprime na tela as informações gerais do dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Estado         5 non-null      object
#  1   Cidade         5 non-null      object
#  2   Habitantes     5 non-null      int64
#  3   Salário-Médio  5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 288.0+ bytes

# %%
cidades.columns # Retorna uma lista com o nome de todas as colunas
# Out:
# Index(['Estado', 'Cidade', 'Habitantes', 'Salário-Médio'], dtype='object')

# %%
cidades['Salário-Médio'].describe() # Retorna um objeto DataFrame com as medidas estatísticas para cada coluna
# Out:
# count       5.000000
# mean     1733.000000
# std       357.459089
# min      1356.000000
# 25%      1508.000000
# 50%      1710.000000
# 75%      1798.000000
# max      2293.000000
# Name: Salário-Médio, dtype: float64

# %%
plt.plot(cidades['Salário-Médio'])

# %% [markdown]
# # **Tipos de Dados com Pandas**

# %%
cidades.dtypes
# Out:
# Estado            object
# Cidade            object
# Habitantes         int64
# Salário-Médio    float64
# dtype: object

# %%
cidades['Habitantes'] = cidades['Habitantes'].astype('float64')
cidades.dtypes
# Out:
# Estado            object
# Cidade            object
# Habitantes       float64
# Salário-Médio    float64
# dtype: object

# %%
cidades['Data'] = ['3/8/2021', '3/9/2021', '3/10/2021', '3/11/2021', '3/12/2021']
cidades['Data'] = pd.to_datetime(cidades['Data'])
cidades
# Out:
#            Estado         Cidade  Habitantes  Salário-Médio       Data
# 0          Paraná       Londrina    575377.0         1356.0 2021-03-08
# 1       São Paulo     São Carlos    254484.0         1508.0 2021-03-09
# 2  Santa Catarina  Florianópolis    508826.0         1798.0 2021-03-10
# 3          Paraná       Curitiba   1963726.0         2293.0 2021-03-11
# 4       São Paulo       Campinas   1223237.0         1710.0 2021-03-12

# %%
cidades['Data'] = cidades['Data'].dt.strftime('%d-%m-%Y') # Dia, Mês, Ano
cidades # Novo Formato
# Out:
#            Estado         Cidade  Habitantes  Salário-Médio        Data
# 0          Paraná       Londrina    575377.0         1356.0  08-03-2021
# 1       São Paulo     São Carlos    254484.0         1508.0  09-03-2021
# 2  Santa Catarina  Florianópolis    508826.0         1798.0  10-03-2021
# 3          Paraná       Curitiba   1963726.0         2293.0  11-03-2021
# 4       São Paulo       Campinas   1223237.0         1710.0  12-03-2021

# %% [markdown]
# # **Renomeando Colunas**

# %%
cidades.rename(columns={'Habitantes': 'N Habitantes', 'Data': 'Data - Censo'}, inplace=True)
cidades
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 0          Paraná       Londrina      575377.0         1356.0   08-03-2021
# 1       São Paulo     São Carlos      254484.0         1508.0   09-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 3          Paraná       Curitiba     1963726.0         2293.0   11-03-2021
# 4       São Paulo       Campinas     1223237.0         1710.0   12-03-2021

# %% [markdown]
# # **Selecionando Linhas e Colunas**

# %%
cidadesHab = cidades[['N Habitantes', 'Salário-Médio']] # Seleciona as duas colunas com os nomes especificados
cidadesHab
# Out:
#    N Habitantes  Salário-Médio
# 0      575377.0         1356.0
# 1      254484.0         1508.0
# 2      508826.0         1798.0
# 3     1963726.0         2293.0
# 4     1223237.0         1710.0

# %%
cidades.loc[1,'N Habitantes'] # Seleciona as duas linhas com os nomes especificados (note que o "rótulo" de cada linha está presente na forma de números inteiros)
# Out:
# 254484.0

# %%
cidades.iloc[1:3] # Seleciona as linhas do dataframe original, referentes ao índice determinado
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 1       São Paulo     São Carlos      254484.0         1508.0   09-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021

# %%
cidades.iloc[:, 0:2] # Seleciona todas as linhas e as duas primeiras colunas do dataframe original
# Out:
#            Estado         Cidade
# 0          Paraná       Londrina
# 1       São Paulo     São Carlos
# 2  Santa Catarina  Florianópolis
# 3          Paraná       Curitiba
# 4       São Paulo       Campinas

# %%
cidades.iloc[1:3, :3] # Seleciona as duas primeiras linhas e as três primeiras colunas
# Out:
#            Estado         Cidade  N Habitantes
# 1       São Paulo     São Carlos      254484.0
# 2  Santa Catarina  Florianópolis      508826.0

# %%
cidades.iloc[:, [1, 3, 0, 2]] # Seleciona todas as linhas e as colunas determinadas
# Out:
#           Cidade  Salário-Médio          Estado  N Habitantes
# 0       Londrina         1356.0          Paraná      575377.0
# 1     São Carlos         1508.0       São Paulo      254484.0
# 2  Florianópolis         1798.0  Santa Catarina      508826.0
# 3       Curitiba         2293.0          Paraná     1963726.0
# 4       Campinas         1710.0       São Paulo     1223237.0

# %% [markdown]
# # **Adicionando e Removendo Colunas**

# %%
cidades.insert(1, 'Sigla', ['PR', 'SP', 'SC', 'PR', 'SP']) # Adiciona novos dados no índice dois
#cidades.insert(3, 'Sigla-Repetida', cidades['Sigla']) # Adiciona uma coluna repetida "Sigla"
cidades
# Out:
#            Estado Sigla         Cidade  N Habitantes  Salário-Médio  \
# 0          Paraná    PR       Londrina      575377.0         1356.0
# 1       São Paulo    SP     São Carlos      254484.0         1508.0
# 2  Santa Catarina    SC  Florianópolis      508826.0         1798.0
# 3          Paraná    PR       Curitiba     1963726.0         2293.0
# 4       São Paulo    SP       Campinas     1223237.0         1710.0
#
#   Data - Censo
# 0   08-03-2021
# 1   09-03-2021
# 2   10-03-2021
# 3   11-03-2021
# 4   12-03-2021

# %%
cidades.pop('Sigla')

# ou

#cidades = cidades.drop(['Sigla-Repetida'], axis=1)
cidades
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 0          Paraná       Londrina      575377.0         1356.0   08-03-2021
# 1       São Paulo     São Carlos      254484.0         1508.0   09-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 3          Paraná       Curitiba     1963726.0         2293.0   11-03-2021
# 4       São Paulo       Campinas     1223237.0         1710.0   12-03-2021

# %% [markdown]
# # **Operações Básicas - Consultas**

# %%
cidades.query('`Salário-Médio` > 1750.0')
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 3          Paraná       Curitiba     1963726.0         2293.0   11-03-2021

# %%
cidades.query('Estado == "São Paulo"')
# Out:
#       Estado      Cidade  N Habitantes  Salário-Médio Data - Censo
# 1  São Paulo  São Carlos      254484.0         1508.0   09-03-2021
# 4  São Paulo    Campinas     1223237.0         1710.0   12-03-2021

# %%
cidades.query('`N Habitantes` > 500000 and `N Habitantes` < 1300000')
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 0          Paraná       Londrina      575377.0         1356.0   08-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 4       São Paulo       Campinas     1223237.0         1710.0   12-03-2021

# %% [markdown]
# # **Operações Básicas - Ordenação**

# %%
cidades.sort_values(by='Cidade', inplace=True)
cidades
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 4       São Paulo       Campinas     1223237.0         1710.0   12-03-2021
# 3          Paraná       Curitiba     1963726.0         2293.0   11-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 0          Paraná       Londrina      575377.0         1356.0   08-03-2021
# 1       São Paulo     São Carlos      254484.0         1508.0   09-03-2021

# %%
cidades.sort_values(by='Salário-Médio', inplace=True)
cidades
# Out:
#            Estado         Cidade  N Habitantes  Salário-Médio Data - Censo
# 0          Paraná       Londrina      575377.0         1356.0   08-03-2021
# 1       São Paulo     São Carlos      254484.0         1508.0   09-03-2021
# 4       São Paulo       Campinas     1223237.0         1710.0   12-03-2021
# 2  Santa Catarina  Florianópolis      508826.0         1798.0   10-03-2021
# 3          Paraná       Curitiba     1963726.0         2293.0   11-03-2021

# %% [markdown]
# # **Operações Básicas - Combinando DataFrames**

# %%
cidades_salarios = pd.DataFrame(
    [
        ['Paraná', 'Londrina', 1356.00],
        ['São Paulo', 'São Carlos', 1508.00],
        ['Santa Catarina', 'Florianópolis', 1798.00],
        ['Paraná', 'Curitiba', 2293.00],
        ['São Paulo', 'Campinas', 1710.00]
    ], columns=['Estado', 'Cidade', 'Salário-Médio'])

cidades_salarios
# Out:
#            Estado         Cidade  Salário-Médio
# 0          Paraná       Londrina         1356.0
# 1       São Paulo     São Carlos         1508.0
# 2  Santa Catarina  Florianópolis         1798.0
# 3          Paraná       Curitiba         2293.0
# 4       São Paulo       Campinas         1710.0

# %%
cidades_pop = pd.DataFrame(
    [
        ['Londrina', 575377],
        ['São Carlos', 254484],
        ['Florianópolis', 508826],
        ['Curitiba', 1963726],
        ['Campinas', 1223237]
    ], columns=['Cidade', 'Habitantes'])

cidades_pop
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826
# 3       Curitiba     1963726
# 4       Campinas     1223237

# %%
pd.merge(left=cidades_salarios, right=cidades_pop, on="Cidade")
# Out:
#            Estado         Cidade  Salário-Médio  Habitantes
# 0          Paraná       Londrina         1356.0      575377
# 1       São Paulo     São Carlos         1508.0      254484
# 2  Santa Catarina  Florianópolis         1798.0      508826
# 3          Paraná       Curitiba         2293.0     1963726
# 4       São Paulo       Campinas         1710.0     1223237

# %%
cidades_df1 = pd.DataFrame(
    [
        ['Londrina', 575377],
        ['São Carlos', 254484],
        ['Florianópolis', 508826],
    ], columns=['Cidade', 'Habitantes'])

cidades_df1
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826

# %%
cidades_df2 = pd.DataFrame(
    [
        ['Curitiba', 1963726],
        ['Campinas', 1223237]
    ], columns=['Cidade', 'Habitantes'])

cidades_df2
# Out:
#      Cidade  Habitantes
# 0  Curitiba     1963726
# 1  Campinas     1223237

# %%
pd.concat([cidades_df1, cidades_df2], ignore_index=True)
# Out:
#           Cidade  Habitantes
# 0       Londrina      575377
# 1     São Carlos      254484
# 2  Florianópolis      508826
# 3       Curitiba     1963726
# 4       Campinas     1223237
